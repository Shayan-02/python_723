# %% [markdown]
# ### List -> x = [, ]

# %%
a = [1, "ali", True, None, 2.5]
a[2] = False
a
# Out:
# [1, 'ali', False, None, 2.5]

# %%
lst = [10, 20, 30 , 10, 20, 30]
# for i in range(10, 21):
#     if i % 2 == 0:
#         lst.append(i)
# for _ in lst:
#     if _ == lst[-1]:
#         print(_)
#     else:
#         print(_, end=" + ")

for _ in range(len(lst)):
    if _ == len(lst) - 1:
        print(lst[_])
    else:
        print(lst[_], end=" + ")

print("c1", end="")
print("continue")
# Out:
# 10 + 20 + 30 + 10 + 20 + 30
# c1continue

# %%
print([_ for _ in range(10, 21) if _ % 2 == 0 and _ >= 12])
# Out:
# [12, 14, 16, 18, 20]

# %% [markdown]
# ### tuple -> x = (, ) or x = 1, 2, 3

# %%
t = (1, 2, 3)
t
# Out:
# (1, 2, 3)

# %%
t[1] = "ali"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 t[1] = "ali"
#
# TypeError: 'tuple' object does not support item assignment

# %%
lt  = list(t)
lt[1] = "ali"
t = tuple(lt)
t
# Out:
# (1, 'ali', 3)

# %%
fruits = ["apple", "banana", "cherry"]
green = fruits[0]
yellow = fruits[1]
red = fruits[2]
print(green, yellow, red)
# Out:
# apple banana cherry

# %% [markdown]
# #### unplace

# %%
fruits = "cucumber" , "apple", "banana", "cherry", "watermelon", "orange" # tuple
green, *yellow, red, purple = fruits
print("green: ", green)
print("yellow: ", yellow)
print("red: ", red)
# Out:
# green:  cucumber
# yellow:  ['apple', 'banana', 'cherry']
# red:  watermelon

# %% [markdown]
# ### set -> {, , }

# %%
s1 = {"ali", "reza", "mohammad"}
s2 = {"sara", "nika", "abbas", "soraya", "armita"}
print(s1[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 3
#       1 s1 = {"ali", "reza", "mohammad"}
#       2 s2 = {"sara", "nika", "abbas", "soraya", "armita"}
# ----> 3 print(s1[1])
#
# TypeError: 'set' object is not subscriptable
